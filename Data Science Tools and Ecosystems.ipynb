# %% [markdown]
# # Data Science Tools and Ecosystems

# %% [markdown]
# In this notebook, Data Science tools are summarized.
#
# **Objectives**
#
# Some popular languages for Data Science are:
# * Python
# * R
# * Java
# * SQL
# * C+

# %% [markdown]
# Some of the commonly used libraries used for Data Scientist include:
#
# 1. Pandas
# 2. NumPy
# 3. Seaborn
# 4. Keras
# 5. Apache Spark

# %% [markdown]
# | **Data Science Tools** |
# | ---------------------- |
# |  Anaconda   |
# |  R Studio |
# |   Jupyter Notebooks   |

# %% [markdown]
# ### Below are a few examples of arithmetic expressions in Python

# %%
#This is a simple artihmetic expression to multiple then add integars

# %%
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by dividing by 60
200//60
# Out:
# 3

# %% [markdown]
# # Objectives
# * Add commments to code cells
# * Create markdown cells
# * Add ordered and unordered lists to markdown cells
# * Format content of markdown cells with heading skills

# %% [markdown]
# **Author(s)**
#
# Lily S
